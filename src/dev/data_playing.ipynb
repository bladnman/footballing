# %%
import sys
sys.path.insert(1, '..')
import game_utils as gu
import pandas as pd

# %%
df = pd.read_csv('../../data/games/all_games.csv')
df
# Out:
#             date  year  week                      team  team_score  \
# 0     2010-09-09  2010     1        New Orleans Saints          14
# 1     2010-09-09  2010     1         Minnesota Vikings           9
# 2     2010-09-12  2010     1             Chicago Bears          19
# 3     2010-09-12  2010     1             Detroit Lions          14
# 4     2010-09-12  2010     1             Buffalo Bills          10
# ...          ...   ...   ...                       ...         ...
# 5301  2021-01-03  2020    17         Las Vegas Raiders          32
# 5302  2021-01-03  2020    17        Indianapolis Colts          28
# 5303  2021-01-03  2020    17      Jacksonville Jaguars          14
# 5304  2021-01-03  2020    17       Philadelphia Eagles          14
# 5305  2021-01-03  2020    17  Washington Football Team          20
#
#                       opponent  opponent_score  win  home
# 0            Minnesota Vikings               9    1     1
# ...

# %%
saints_all = df[df['team'] == 'New Orleans Saints']
saints_2020 = saints_all[saints_all['year'] == 2020]
saints_2020
# Out:
#             date  year  week                team  team_score  \
# 4838  2020-09-13  2020     1  New Orleans Saints          34
# 4875  2020-09-21  2020     2  New Orleans Saints          24
# 4902  2020-09-27  2020     3  New Orleans Saints          30
# 4921  2020-10-04  2020     4  New Orleans Saints          35
# 5000  2020-10-25  2020     7  New Orleans Saints          27
# 5065  2020-11-08  2020     9  New Orleans Saints          38
# 5090  2020-11-15  2020    10  New Orleans Saints          27
# 5104  2020-11-22  2020    11  New Orleans Saints          24
# 5143  2020-11-29  2020    12  New Orleans Saints          31
# 5155  2020-12-06  2020    13  New Orleans Saints          21
# 5205  2020-12-13  2020    14  New Orleans Saints          21
# 5236  2020-12-20  2020    15  New Orleans Saints          29
# 5242  2020-12-25  2020    16  New Orleans Saints          52
# 5291  2021-01-03  2020    17  New Orleans Saints          33
#
# ...
