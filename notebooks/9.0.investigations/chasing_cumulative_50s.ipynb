# %% [markdown]
# # Chasing Aggregates
#
# It looks like all of our `cml_` fields are hovering around `50%`. That makes is feel like we are calculating the for and against at the same time. This is wrong for all of these fields.
#
# ## Steps to Investigate
# - Set up test to `calculate aggregates` for a single year
# - Print out some aggregate for that year, week by week for a team
#   as well as the other meaningful data for that team

# %%
import utils.game_utils as gu
import utils.plot as guplot

import math
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import matplotlib.patches as mpatches

nfld = gu.NFL_Data()

YEAR = 2018
WEEK = 14
TEAM = gu.TEAM_NAME['Saints']

# %% [markdown]
# ## Calculate Aggregates

# %%
# TBD - once we have the data presenting below

# %% [markdown]
# ## Print Aggregates for the week
#
# Intent here is to see the data for a team by-week so that we can see the aggregation at work. A visualization may be helpful as well.

# %%
FIELDS = gu.COMMON_FIELDS + [
  'team_cml_pass_yards_before',
  'team_pass_yards',
  'team_cml_pass_yards_after',
]

nfl_df = nfld.data_by_team()
year_df = gu.get_year(nfl_df, YEAR)
team_df = year_df[year_df['team'] == TEAM]
team_df[FIELDS]
# Out:
#             date  year  week                team  team_score  \
# 4106  2018-09-09  2018     1  New Orleans Saints          40
# 4144  2018-09-16  2018     2  New Orleans Saints          21
# 4165  2018-09-23  2018     3  New Orleans Saints          43
# 4217  2018-09-30  2018     4  New Orleans Saints          33
# 4250  2018-10-08  2018     5  New Orleans Saints          43
# 4301  2018-10-21  2018     7  New Orleans Saints          24
# 4335  2018-10-28  2018     8  New Orleans Saints          30
# 4358  2018-11-04  2018     9  New Orleans Saints          45
# 4367  2018-11-11  2018    10  New Orleans Saints          51
# 4412  2018-11-18  2018    11  New Orleans Saints          48
# 4422  2018-11-22  2018    12  New Orleans Saints          31
# 4449  2018-11-29  2018    13  New Orleans Saints          10
# 4487  2018-12-09  2018    14  New Orleans Saints          28
# 4543  2018-12-17  2018    15  New Orleans Saints          12
# 4570  2018-12-23  2018    16  New Orleans Saints          31
# 4586  2018-12-30  2018    17  New Orleans Saints          14
#
#                   opponent  opponent_score  win  home  \
# 4106  Tampa Bay Buccaneers              48    0     1
# 4144      Cleveland Browns              18    1     1
# 4165       Atlanta Falcons              37    1     0
# 4217       New York Giants              18    1     0
# 4250   Washington Redskins              19    1     1
# 4301      Baltimore Ravens              23    1     0
# 4335     Minnesota Vikings              20    1     0
# 4358      Los Angeles Rams              35    1     1
# 4367    Cincinnati Bengals              14    1     0
# 4412   Philadelphia Eagles               7    1     1
# 4422       Atlanta Falcons              17    1     1
# 4449        Dallas Cowboys              13    0     0
# 4487  Tampa Bay Buccaneers              14    1     0
# 4543     Carolina Panthers               9    1     0
# 4570   Pittsburgh Steelers              28    1     1
# 4586     Carolina Panthers              33    0     1
#
#       team_cml_pass_yards_before  team_pass_yards  team_cml_pass_yards_after
# 4106                           0              439                        439
# 4144                         439              243                        682
# 4165                         682              396                       1078
# 4217                        1078              227                       1305
# 4250                        1305              363                       1668
# 4301                        1668              212                       1880
# 4335                        1880              164                       2044
# 4358                        2044              346                       2390
# 4367                        2390              265                       2655
# 4412                        2655              373                       3028
# 4422                        3028              171                       3199
# 4449                        3199              127                       3326
# 4487                        3326              201                       3527
# 4543                        3527              203                       3730
# 4570                        3730              326                       4056
# 4586                        4056              118                       4174

# %% [markdown]
# ### Checking if accumulation is not working
#
# The below goes through all `cml` fields to see if their `_after_` is equal to `_before + current`. At the time of this writing there were no examples where this was incorrect.

# %%
nfl_df = nfld.data_by_team()
year_df = gu.get_year(nfl_df, YEAR)

cols = nfl_df.columns
team_cml_cols = pd.Series(cols[cols.str.contains('team_cml_')]).sort_values()
cml_cols = team_cml_cols.apply(lambda x: x.replace('team_', '')).values
# cml_cols = team_cml_cols.values

df = nfl_df
for col in cml_cols:
  if "_perf" not in col:
    root_field = cml_root_field = col.replace('cml_', '').replace('_before', '').replace('_after', '')
    if root_field == 'points': 
      root_field = 'score'
    l = len(df[df[f'team_cml_{cml_root_field}_after'] != (df[f'team_cml_{cml_root_field}_before']+df[f'team_{root_field}'])])
    print(f"[{l}] {root_field}")
# Out:
# [0] first_downs
# [0] first_downs
# [0] fumble_gained
# [0] fumble_gained
# [0] fumble_lost
# [0] fumble_lost
# [0] interceptions_gained
# [0] interceptions_gained
# [0] interceptions_lost
# [0] interceptions_lost
# [0] pass_completions
# [0] pass_completions
# [0] pass_count
# [0] pass_count
# [0] pass_yards
# [0] pass_yards
# [0] penalty_count
# [0] penalty_count
# [0] score
# [0] score
# [0] rush_count
# [0] rush_count
# [0] rush_yards
# [0] rush_yards
# [0] sack_count
# [0] sack_count
# [0] sack_gained
# [0] sack_gained
# [0] top_sec
# [0] top_sec
# [0] total_yards
# [0] total_yards
# [0] turnovers_gained
# [0] turnovers_gained
# [0] turnovers_lost
# [0] turnovers_lost

# %% [markdown]
# # TESTER : CML Values for all data
#
# The below shows that all fields are 50%, 55%, 45% and the like. Rerunning the below should get us data much more separated once things are fixed.

# %%
### 
### CML PERCENTAGES
### 

def get_perc(df, field):
  '''
  Given a df and a field, return the number of time the 
  winning team lead in that field.
  
  If there is a '!' in the field name the invert the 
  logic
  '''
  if field.startswith('!'):
    field = field.replace('!','')
    wins_df = df[
      ((df['win'] == 0) & (df[f'team_{field}'] > df[f'opponent_{field}']))|
      ((df['win'] == 1) & (df[f'team_{field}'] <= df[f'opponent_{field}']))
    ]
  else:
    wins_df = df[
        ((df['win'] == 1) & (df[f'team_{field}'] > df[f'opponent_{field}']))|
        ((df['win'] == 0) & (df[f'team_{field}'] <= df[f'opponent_{field}']))
      ]

  return (len(wins_df) / len(df)) * 100
def work_fields(df, fields):
  data = {}
  for field in fields:
    data[field] = get_perc(df, field)
  return data

nfl_df = nfld.data_by_game()

# read in all CML columns and build an
# array of them (without team_ and opponent_)
cols = nfl_df.columns
team_cml_cols = pd.Series(cols[cols.str.contains('team_cml_')]).sort_values()
cml_cols = team_cml_cols.apply(lambda x: x.replace('team_', '')).values

data = work_fields(gu.get_year(nfl_df, 2021), cml_cols)

# array each item so it can be DF'd
for item in data: data[item] = [data[item]]
pdf = pd.DataFrame(data)

# pdf = pdf.T.sort_values(by=0).T
pdf.T
# Out:
#                                          0
# cml_comb_comp_perf_after         63.636364
# cml_comb_comp_perf_before        51.515152
# cml_comb_def_perf_after          63.636364
# cml_comb_def_perf_before         51.515152
# cml_comb_off_perf_after          63.636364
# cml_comb_off_perf_before         51.515152
# cml_first_downs_after            61.818182
# cml_first_downs_before           58.787879
# cml_fumble_gained_after          55.151515
# cml_fumble_gained_before         47.272727
# cml_fumble_lost_after            53.939394
# cml_fumble_lost_before           58.181818
# cml_interceptions_gained_after   64.848485
# cml_interceptions_gained_before  60.000000
# cml_interceptions_lost_after     46.666667
# cml_interceptions_lost_before    55.151515
# cml_pass_comp_perf_after         52.121212
# cml_pass_comp_perf_before        51.515152
# cml_pass_completions_after       51.515152
# cml_pass_completions_before      53.939394
# cml_pass_count_after             46.060606
# cml_pass_count_before            53.939394
# cml_pass_def_perf_after          52.121212
# cml_pass_def_perf_before         51.515152
# cml_pass_off_perf_after          52.121212
# cml_pass_off_perf_before         51.515152
# cml_pass_yards_after             53.939394
# cml_pass_yards_before            53.333333
# cml_penalty_count_after          50.909091
# cml_penalty_count_before         54.545455
# cml_points_after                 70.303030
# cml_points_before                54.545455
# cml_rush_comp_perf_after         62.424242
# cml_rush_comp_perf_before        51.515152
# cml_rush_count_after             56.969697
# cml_rush_count_before            47.272727
# cml_rush_def_perf_after          62.424242
# cml_rush_def_perf_before         51.515152
# cml_rush_off_perf_after          62.424242
# cml_rush_off_perf_before         51.515152
# cml_rush_yards_after             58.181818
# cml_rush_yards_before            48.484848
# cml_sack_count_after             41.818182
# cml_sack_count_before            46.666667
# cml_sack_gained_after            52.727273
# cml_sack_gained_before           45.454545
# cml_top_sec_after                58.787879
# cml_top_sec_before               53.333333
# cml_total_yards_after            60.606061
# cml_total_yards_before           54.545455
# cml_turnovers_gained_after       65.454545
# cml_turnovers_gained_before      55.757576
# cml_turnovers_lost_after         41.818182
# cml_turnovers_lost_before        56.363636
